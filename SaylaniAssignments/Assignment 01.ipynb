# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Write your code here
print("My name is Muhammad Rabi Khan.\nMy father name is Khan Muhammad Ali\nMy date of birth is 28 of april 2005.")

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here
bio1 = "I am Muhammad Rabi Khan and I love to study, play games.\n"
bio2 = "In addition to that, I am currently living in Karachi."

print(bio1, bio2)

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here
a = 10
b = 20

#arithmetic operators
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a % b)
print(a ** b)
print(a // b)

#comparison operators
print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)

#assignment operators
x = 3
x += 3
x -= 2
x *= 3
x /= 5
x %= 4

print(x)

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here
english = 50
maths = 78
islamiyat = 81

total_marks = 300

summ = english + maths + islamiyat
print("Obtained marks: ", summ)

percentage = (summ / total_marks) * 100
print("Percentage: ", percentage)
