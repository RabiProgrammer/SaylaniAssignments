# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
user = float(input("Enter your current salary:"))
years = int(input("Enter your year of service:"))

if(years > 5):
    netbonus = user * 0.05
else:
    print("No bonus increment. Service must be more than 5 years.")

print("Bonus incremented to ", netbonus)
# Out:
# Running cells with 'Python 3.12.8' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/msys64/mingw64/bin/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
age = int(input("Enter your age:"))

if(age > 17):
    print("You are eligible to vote.")
else:
    print("Sorry, you must be 18 to vote.")

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here

user = int(input("Enter a number: "))

if(user % 2 == 0):
    print("The number is even.")
else:
    print("The number is odd.")

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here

num = int(input("Enter a number: "))

if(num % 7 == 0):
    print("The number is divisible by 7.")
else:
    print("The number is not divisible by 7.")
# Out:
# Running cells with 'Python 3.12.8' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here

num = int(input("Enter a number: "))

if(num % 5 == 0):
    print("Hello")
else:
    print("bye")

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here

num = int(input("Enter 5 digits in a row: "))
last = abs(num) % 10
print("The last digit: ", last)

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 

length = float(input("Enter the length: "))
breadth = float(input("Enter the breadth: "))

if(breadth == length):
    print("It is a square.")
else:
    print("It is a rectangle.")

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here

user1 = int(input("Enter your first num: "))
user2 = int(input("Enter your second num: "))

if(user1 > user2):
    print("User 1 is the greatest.")
else:
    print("User 2 is the greatest.")

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
price = 100
item = int(input("Enter the total items: "))

total = price * item

if(total > 1000):
    discount = total * 0.10
    total = total - discount
    print("Discount price: ", total)
else:
    print("No discount.")

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here

marks = float(input("Enter your marks: "))

if(marks >= 80):
    print("A grade")
elif(marks >= 60 and marks < 80):
    print("B grade")
elif(marks >= 50 and marks < 60):
    print("C grade")
elif(marks >= 45 and marks < 50):
    print("D grade")
elif(marks >= 25 and marks < 45):
    print("E grade")
else:
    print("F grade")

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here

no_of_classes_held = float(input("Enter the number of classes held: "))
no_of_classes_attend = float(input("Enter the number of classes student attended: "))

percentage = (no_of_classes_attend / no_of_classes_held) * 100
print(percentage)
print()

if(percentage < 75):
    print("You are not allowed to sit in the exams.")
else:
    print("You are allowed to sit in the exams.")

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
no_of_classes_held = float(input("Enter the number of classes held: "))
no_of_classes_attend = float(input("Enter the number of classes student attended: "))

percentage = (no_of_classes_attend / no_of_classes_held) * 100
print("Attended percentage: ", percentage)
print()
medical = input("Did you have a medical cause? (Y/N)")

if(percentage < 75):
    print("You are not allowed to sit in the exams.")
elif(percentage >= 75 or medical.upper() == 'Y'):
    print("You are allowed to sit in the exams.")

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here

year = int(input("Enter an year: "))

if(year % 4 == 0):
    print("The year is/was a leap year.")
elif(year % 4 != 0):
    print("The year is/was not a leap year.")

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
gender = input("Enter your gender (M/F): ")
marital = input("Enter your marital status (Y/N): ")
age = int(input("Enter your age: "))

if(gender == 'F'):
    print("You can work only in urban areas.")
elif(gender == 'M' and age > 20 and age <= 40):
    print("You can work anywhere.")
elif(gender == 'M' and age > 40 and age <= 60):
    print("You can work only in urban areas.")
else:
    print("ERROR")

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here

#question 6

units = int(input("Enter the number of electricity units: "))
bill = 0

if(units <= 100):
    bill = 0
elif(units <= 300):
    bill = (units - 100) * 5
else:
    bill = (200 * 5) + ((units - 300) * 10)

print("Total bill amount: Rs.", bill)

#question 13

age1 = int(input("Enter your age user1: "))
age2 = int(input("Enter your age user2: "))
age3 = int(input("Enter your age user3: "))

if(age1 > age2 and age1 > age3):
    print("user1 is the oldest")
elif(age2 > age1 and age2 > age3):
    print("user2 is the oldest")
else:
    print("user3 is the oldest")

if(age1 < age2 and age1 < age3):
    print("user1 is the youngest")
elif(age2 < age1 and age2 < age3):
    print("user2 is the youngest")
else:
    print("user3 is the youngest.")
